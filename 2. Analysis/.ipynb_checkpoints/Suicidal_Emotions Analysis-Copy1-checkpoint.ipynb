# %% [markdown]
# # <span style='color:blue'> CDS 522 Text and Speech Analytics Project : </span>
# ## <span style='color:blue'> Text Analytics for Suicidal Thoughts </span>
#
# **Prepared by:
# Chin Yi Xiang,
# Ling Hui Ting**

# %% [markdown]
# # Emotions Analysis
# *

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pickle
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter

# %%
# Read files # Download files from NRC Emotion and Sentiment Lexicons
fear = pd.read_csv('D:/USM/CDS 522/Project/emotions/fear-scores.txt', 
                   header = None, sep="\t", names=['English','Scores'])
fear['Emotions']= "Fear"


anger = pd.read_csv('D:/USM/CDS 522/Project/emotions/anger-scores.txt', 
                   header = None, sep="\t", names=['English','Scores'])
anger['Emotions']= "Anger"


disgust = pd.read_csv('D:/USM/CDS 522/Project/emotions/disgust-scores.txt', 
                   header = None, sep="\t", names=['English','Scores'])
disgust['Emotions']= "Disgust"


sadness = pd.read_csv('D:/USM/CDS 522/Project/emotions/sadness-scores.txt', 
                   header = None, sep="\t", names=['English','Scores'])
sadness['Emotions']= "Sadness"


surprise = pd.read_csv('D:/USM/CDS 522/Project/emotions/surprise-scores.txt', 
                   header = None, sep="\t", names=['English','Scores'])
surprise['Emotions']= "Surprise"

# %%
# Remove the words where probabilily < 20% of the emotions
fear= fear.drop(fear[fear['Scores'] < 0.2].index, inplace=False).reset_index(drop=True)
anger= anger.drop(anger[anger['Scores'] < 0.2].index, inplace=False).reset_index(drop=True)
disgust= disgust.drop(disgust[disgust['Scores'] < 0.2].index, inplace=False).reset_index(drop=True)
sadness= sadness.drop(sadness[sadness['Scores'] < 0.2].index, inplace=False).reset_index(drop=True)
surprise= surprise.drop(surprise[surprise['Scores'] < 0.2].index, inplace=False).reset_index(drop=True)

# %%
# combined all the files
df_emo = fear.append(anger).append(disgust).append(sadness).append((surprise), ignore_index=True)
df_emo
# Out:
#          English  Scores  Emotions
# 0        torture   0.984      Fear
# 1      terrorist   0.972      Fear
# 2       horrific   0.969      Fear
# 3      terrorism   0.969      Fear
# 4     terrorists   0.969      Fear
# ...          ...     ...       ...
# 5732       sweet   0.203  Surprise
# 5733      purity   0.203  Surprise
# 5734     nullify   0.203  Surprise
# 5735      morals   0.203  Surprise
# 5736       money   0.203  Surprise
#
# [5737 rows x 3 columns]

# %%
# convert to pivot
pivot_emo = df_emo.pivot_table(index=['English'], columns= ['Emotions'], values=['Scores'], aggfunc='sum')
pivot_emo = pivot_emo.fillna(value=0)
pivot_emo
# Out:
#             Scores
# Emotions     Anger Disgust   Fear Sadness Surprise
# English
# aaaaaaah     0.000     0.0  0.344   0.000    0.000
# aaaah        0.000     0.0  0.234   0.000    0.000
# abandon      0.000     0.0  0.531   0.703    0.000
# abandoned    0.222     0.0  0.534   0.828    0.000
# abandonment  0.438     0.0  0.609   0.859    0.523
# ...            ...     ...    ...     ...      ...
# yelp         0.000     0.0  0.281   0.000    0.516
# yousuck      0.578     0.0  0.000   0.000    0.000
# yucky        0.000     0.0  0.000   0.203    0.000
# zany         0.000     0.0  0.000   0.000    0.555
# zeal         0.000     0.0  0.000   0.000    0.484
#
# [3424 rows x 5 columns]

# %%
# rename the columns and index
pivot_emo.reset_index(inplace = True)
pivot_emo.columns=['Words','Anger','Disgust','Fear','Sadness','Surprise']
pivot_emo
# Out:
#             Words  Anger  Disgust   Fear  Sadness  Surprise
# 0        aaaaaaah  0.000      0.0  0.344    0.000     0.000
# 1           aaaah  0.000      0.0  0.234    0.000     0.000
# 2         abandon  0.000      0.0  0.531    0.703     0.000
# 3       abandoned  0.222      0.0  0.534    0.828     0.000
# 4     abandonment  0.438      0.0  0.609    0.859     0.523
# ...           ...    ...      ...    ...      ...       ...
# 3419         yelp  0.000      0.0  0.281    0.000     0.516
# 3420      yousuck  0.578      0.0  0.000    0.000     0.000
# 3421        yucky  0.000      0.0  0.000    0.203     0.000
# 3422         zany  0.000      0.0  0.000    0.000     0.555
# 3423         zeal  0.000      0.0  0.000    0.000     0.484
#
# [3424 rows x 6 columns]

# %%
# add Emotions column (max scores)
emo = pivot_emo
emo['Emotions'] = emo.iloc[:,1:].idxmax(axis=1)
emo
# Out:
#             Words  Anger  Disgust   Fear  Sadness  Surprise  Emotions
# 0        aaaaaaah  0.000      0.0  0.344    0.000     0.000      Fear
# 1           aaaah  0.000      0.0  0.234    0.000     0.000      Fear
# 2         abandon  0.000      0.0  0.531    0.703     0.000   Sadness
# 3       abandoned  0.222      0.0  0.534    0.828     0.000   Sadness
# 4     abandonment  0.438      0.0  0.609    0.859     0.523   Sadness
# ...           ...    ...      ...    ...      ...       ...       ...
# 3419         yelp  0.000      0.0  0.281    0.000     0.516  Surprise
# 3420      yousuck  0.578      0.0  0.000    0.000     0.000     Anger
# 3421        yucky  0.000      0.0  0.000    0.203     0.000   Sadness
# 3422         zany  0.000      0.0  0.000    0.000     0.555  Surprise
# 3423         zeal  0.000      0.0  0.000    0.000     0.484  Surprise
#
# [3424 rows x 7 columns]

# %%
# check if balanced emotions
emo['Emotions'].value_counts()
# Out:
# Fear        932
# Anger       796
# Sadness     722
# Disgust     528
# Surprise    446
# Name: Emotions, dtype: int64

# %%
import emoji

print('Angry: \U0001F621')
print('Sadness: \U0001F630')
print('Fear: \U0001F616')
print('Disgust: \U0001F922')
print('Surprise: \U0001F632')
# Out:
# Angry: 😡
# Sadness: 😰
# Fear: 😖
# Disgust: 🤢
# Surprise: 😲

# %% [markdown]
# # Annotate Emotions

# %%
data_clean = pd.read_pickle('data_clean.pkl')
data_clean
# Out:
# 0       fuck hate holiday season first thanksgiving no...
# 1                           dm add discord want help talk
# 2       im nearly always battle depression get old sta...
# 3       future nothing impenetrable fog look back time...
# 4       always fight sister always lash mom dont anyth...
#                               ...
# 1284    since felt depressed almost take life go away ...
# 1285    dont know im reach time seem appropriate since...
# 1286    dont believe afterlife stay night fear afterli...
# 1287    dont think actually kill thats im scar dont wa...
# 1288    wanna die badly everytime hear someone el suic...
# Name: text, Length: 1289, dtype: object

# %%
# annotate data
def annotate_emotion(wordlist):
    annotated_list = []
    emotion_by_count = {
        'Anger': 0,
        'Fear': 0,
        'Disgust': 0,
        'Sadness': 0,
        'Surprise': 0,
    }
    emotion_by_score = {
        'Anger': 0,
        'Fear': 0,
        'Disgust': 0,
        'Sadness': 0,
        'Surprise': 0,
    }
    for word in wordlist:
        emo_row = emo[emo["Words"] == word]
        if len(emo_row) == 0:
            continue
        else:
            emo_row = emo_row.iloc[0]
        annotated_list.append({
            'word': word,
            'Anger': emo_row['Anger'],
            'Fear': emo_row['Fear'],
            'Disgust': emo_row['Disgust'],
            'Sadness': emo_row['Sadness'],
            'Surprise': emo_row['Surprise'],
            'Emotions': emo_row['Emotions']            
        })
        emotion_by_count[emo_row['Emotions']] += 1
        for ele in emotion_by_score:
            emotion_by_score[ele] += emo_row[ele]
    
    return{
        'annotated_list': annotated_list,
        'emotion_by_count': emotion_by_count,
        'emotion_by_score': emotion_by_score,
    }
        
data_split = data_clean.str.split(' ')
df_annotate = pd.DataFrame(data_split)
annotated = []
emotion_by_count = []
emotion_by_score = []
for i in df_annotate.index:
    row = df_annotate.loc[i].iloc[0]
    res = annotate_emotion(row)
    annotated.append(res['annotated_list'])
    emotion_by_count.append(res['emotion_by_count'])
    emotion_by_score.append(res['emotion_by_score'])
df_annotate['annotated'] = annotated
df_annotate['emotion_by_count'] = emotion_by_count
df_annotate['emotion_by_score'] = emotion_by_score
df_annotate
# Out:
#                                                    text  \
# 0     [fuck, hate, holiday, season, first, thanksgiv...
# 1                  [dm, add, discord, want, help, talk]
# 2     [im, nearly, always, battle, depression, get, ...
# 3     [future, nothing, impenetrable, fog, look, bac...
# 4     [always, fight, sister, always, lash, mom, don...
# ...                                                 ...
# 1284  [since, felt, depressed, almost, take, life, g...
# 1285  [dont, know, im, reach, time, seem, appropriat...
# 1286  [dont, believe, afterlife, stay, night, fear, ...
# 1287  [dont, think, actually, kill, thats, im, scar,...
# 1288  [wanna, die, badly, everytime, hear, someone, ...
#
#                                               annotated  \
# 0     [{'word': 'hate', 'Anger': 0.828, 'Fear': 0.48...
# 1     [{'word': 'discord', 'Anger': 0.57600000000000...
# 2     [{'word': 'battle', 'Anger': 0.697000000000000...
# 3     [{'word': 'unable', 'Anger': 0.0, 'Fear': 0.0,...
# 4     [{'word': 'fight', 'Anger': 0.667, 'Fear': 0.7...
# ...                                                 ...
# 1284  [{'word': 'depressed', 'Anger': 0.297, 'Fear':...
# 1285  [{'word': 'danger', 'Anger': 0.0, 'Fear': 0.80...
# 1286  [{'word': 'fear', 'Anger': 0.5, 'Fear': 0.828,...
# 1287  [{'word': 'kill', 'Anger': 0.0, 'Fear': 0.9620...
# 1288  [{'word': 'die', 'Anger': 0.0, 'Fear': 0.76599...
#
#                                        emotion_by_count  \
# 0     {'Anger': 4, 'Fear': 0, 'Disgust': 0, 'Sadness...
# 1     {'Anger': 1, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 2     {'Anger': 2, 'Fear': 11, 'Disgust': 2, 'Sadnes...
# 3     {'Anger': 0, 'Fear': 0, 'Disgust': 0, 'Sadness...
# 4     {'Anger': 2, 'Fear': 3, 'Disgust': 0, 'Sadness...
# ...                                                 ...
# 1284  {'Anger': 3, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 1285  {'Anger': 3, 'Fear': 10, 'Disgust': 0, 'Sadnes...
# 1286  {'Anger': 0, 'Fear': 6, 'Disgust': 0, 'Sadness...
# 1287  {'Anger': 3, 'Fear': 5, 'Disgust': 1, 'Sadness...
# 1288  {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
#
#                                        emotion_by_score
# 0     {'Anger': 3.694, 'Fear': 4.452999999999999, 'D...
# 1     {'Anger': 0.5760000000000001, 'Fear': 0.203, '...
# 2     {'Anger': 6.7250000000000005, 'Fear': 7.694000...
# 3     {'Anger': 0.636, 'Fear': 0.898, 'Disgust': 0.6...
# 4     {'Anger': 2.886, 'Fear': 3.379, 'Disgust': 0.3...
# ...                                                 ...
# 1284  {'Anger': 2.952, 'Fear': 2.6279999999999997, '...
# 1285  {'Anger': 5.202999999999999, 'Fear': 12.612, '...
# 1286  {'Anger': 2.5389999999999997, 'Fear': 6.389, '...
# 1287  {'Anger': 2.643, 'Fear': 4.7440000000000015, '...
# 1288  {'Anger': 1.082, 'Fear': 2.9269999999999996, '...
#
# [1289 rows x 4 columns]

# %%
#show example
sample_row = df_annotate.iloc[0]
print('Before annotate: \n','-'*20)
print(sample_row['text'])
print('After annotates: \n','-'*20)
print(sample_row['annotated'])
print('\nemotion_by_count', sample_row['emotion_by_count'])
print('\nemotion_by_score', sample_row['emotion_by_score'])
# Out:
# Before annotate:
#  --------------------
# ['fuck', 'hate', 'holiday', 'season', 'first', 'thanksgiving', 'nothing', 'thankful', 'everyone', 'hate', 'hate', 'would', 'thankful', 'would', 'fuck', 'die', 'already', 'next', 'christmas', 'one', 'time', 'year', 'people', 'actually', 'nice', 'day', 'go', 'back', 'shitty', 'fuck', 'hate', 'new', 'year', 'day', 'start', 'new', 'year', 'loneliness', 'despair', 'really', 'wish', 'could', 'fuck', 'die', 'fuck', 'life']
# After annotates:
#  --------------------
# [{'word': 'hate', 'Anger': 0.828, 'Fear': 0.484, 'Disgust': 0.695, 'Sadness': 0.6559999999999999, 'Surprise': 0.0, 'Emotions': 'Anger'}, {'word': 'hate', 'Anger': 0.828, 'Fear': 0.484, 'Disgust': 0.695, 'Sadness': 0.6559999999999999, 'Surprise': 0.0, 'Emotions': 'Anger'}, {'word': 'hate', 'Anger': 0.828, 'Fear': 0.484, 'Disgust': 0.695, 'Sadness': 0.6559999999999999, 'Surprise': 0.0, 'Emotions': 'Anger'}, {'word': 'die', 'Anger': 0.0, 'Fear': 0.7659999999999999, 'Disgust': 0.0, 'Sadness': 0.773, 'Surprise': 0.0, 'Emotions': 'Sadness'}, {'word': 'shitty', 'Anger': 0.0, 'Fear': 0.0, 'Disgust': 0.0, 'Sadness': 0.6559999999999999, 'Surprise': 0.0, 'Emotions': 'Sadness'}, {'word': 'hate', 'Anger': 0.828, 'Fear': 0.484, 'Disgust': 0.695, 'Sadness': 0.6559999999999999, 'Surprise': 0.0, 'Emotions': 'Anger'}, {'word': 'start', 'Anger': 0.0, 'Fear': 0.0, 'Disgust': 0.0, 'Sadness': 0.0, 'Surprise': 0.344, 'Emotions': 'Surprise'}, {'word': 'loneliness', 'Anger': 0.0, 'Fear': 0.344, 'Disgust': 0.0, 'Sadness': 0.7659999999999999, 'Surprise': 0.0, 'Emotions': 'Sadness'}, {'word': 'despair', 'Anger': 0.382, 'Fear': 0.6409999999999999, 'Disgust': 0.445, 'Sadness': 0.812, 'Surprise': 0.0, 'Emotions': 'Sadness'}, {'word': 'die', 'Anger': 0.0, 'Fear': 0.7659999999999999, 'Disgust': 0.0, 'Sadness': 0.773, 'Surprise': 0.0, 'Emotions': 'Sadness'}]
#
# emotion_by_count {'Anger': 4, 'Fear': 0, 'Disgust': 0, 'Sadness': 5, 'Surprise': 1}
#
# emotion_by_score {'Anger': 3.694, 'Fear': 4.452999999999999, 'Disgust': 3.2249999999999996, 'Sadness': 6.403999999999999, 'Surprise': 0.344}

# %%
df_annotate['domain_emotion_by_count'] = df_annotate['emotion_by_count'].apply(lambda d: max(d,key=d.get))
df_annotate['domain_emotion_by_score'] = df_annotate['emotion_by_score'].apply(lambda d: max(d,key=d.get))
df_annotate
# Out:
#                                                    text  \
# 0     [fuck, hate, holiday, season, first, thanksgiv...
# 1                  [dm, add, discord, want, help, talk]
# 2     [im, nearly, always, battle, depression, get, ...
# 3     [future, nothing, impenetrable, fog, look, bac...
# 4     [always, fight, sister, always, lash, mom, don...
# ...                                                 ...
# 1284  [since, felt, depressed, almost, take, life, g...
# 1285  [dont, know, im, reach, time, seem, appropriat...
# 1286  [dont, believe, afterlife, stay, night, fear, ...
# 1287  [dont, think, actually, kill, thats, im, scar,...
# 1288  [wanna, die, badly, everytime, hear, someone, ...
#
#                                               annotated  \
# 0     [{'word': 'hate', 'Anger': 0.828, 'Fear': 0.48...
# 1     [{'word': 'discord', 'Anger': 0.57600000000000...
# 2     [{'word': 'battle', 'Anger': 0.697000000000000...
# 3     [{'word': 'unable', 'Anger': 0.0, 'Fear': 0.0,...
# 4     [{'word': 'fight', 'Anger': 0.667, 'Fear': 0.7...
# ...                                                 ...
# 1284  [{'word': 'depressed', 'Anger': 0.297, 'Fear':...
# 1285  [{'word': 'danger', 'Anger': 0.0, 'Fear': 0.80...
# 1286  [{'word': 'fear', 'Anger': 0.5, 'Fear': 0.828,...
# 1287  [{'word': 'kill', 'Anger': 0.0, 'Fear': 0.9620...
# 1288  [{'word': 'die', 'Anger': 0.0, 'Fear': 0.76599...
#
#                                        emotion_by_count  \
# 0     {'Anger': 4, 'Fear': 0, 'Disgust': 0, 'Sadness...
# 1     {'Anger': 1, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 2     {'Anger': 2, 'Fear': 11, 'Disgust': 2, 'Sadnes...
# 3     {'Anger': 0, 'Fear': 0, 'Disgust': 0, 'Sadness...
# 4     {'Anger': 2, 'Fear': 3, 'Disgust': 0, 'Sadness...
# ...                                                 ...
# 1284  {'Anger': 3, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 1285  {'Anger': 3, 'Fear': 10, 'Disgust': 0, 'Sadnes...
# 1286  {'Anger': 0, 'Fear': 6, 'Disgust': 0, 'Sadness...
# 1287  {'Anger': 3, 'Fear': 5, 'Disgust': 1, 'Sadness...
# 1288  {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
#
#                                        emotion_by_score  \
# 0     {'Anger': 3.694, 'Fear': 4.452999999999999, 'D...
# 1     {'Anger': 0.5760000000000001, 'Fear': 0.203, '...
# 2     {'Anger': 6.7250000000000005, 'Fear': 7.694000...
# 3     {'Anger': 0.636, 'Fear': 0.898, 'Disgust': 0.6...
# 4     {'Anger': 2.886, 'Fear': 3.379, 'Disgust': 0.3...
# ...                                                 ...
# 1284  {'Anger': 2.952, 'Fear': 2.6279999999999997, '...
# 1285  {'Anger': 5.202999999999999, 'Fear': 12.612, '...
# 1286  {'Anger': 2.5389999999999997, 'Fear': 6.389, '...
# 1287  {'Anger': 2.643, 'Fear': 4.7440000000000015, '...
# 1288  {'Anger': 1.082, 'Fear': 2.9269999999999996, '...
#
#      domain_emotion_by_count domain_emotion_by_score
# 0                    Sadness                 Sadness
# 1                      Anger                   Anger
# 2                       Fear                 Sadness
# 3                    Sadness                 Sadness
# 4                       Fear                    Fear
# ...                      ...                     ...
# 1284                   Anger                   Anger
# 1285                 Sadness                    Fear
# 1286                    Fear                    Fear
# 1287                    Fear                    Fear
# 1288                 Sadness                 Sadness
#
# [1289 rows x 6 columns]

# %%
#Show different by count and by score
df_annotate[df_annotate['domain_emotion_by_count'] != df_annotate['domain_emotion_by_score']]
# Out:
#                                                    text  \
# 2     [im, nearly, always, battle, depression, get, ...
# 6     [sometimes, think, act, tell, someone, want, k...
# 8     [everyones, leave, feel, like, one, anymore, m...
# 22    [dont, really, want, die, cant, live, life, ho...
# 25    [one, hand, wouldnt, mind, die, sleep, natural...
# ...                                                 ...
# 1271  [dont, know, happen, like, week, youre, extrem...
# 1273  [much, corruption, much, greed, year, go, feel...
# 1275  [dont, see, way, im, tire, fail, everything, p...
# 1279  [feel, like, give, want, die, im, tire, try, t...
# 1285  [dont, know, im, reach, time, seem, appropriat...
#
#                                               annotated  \
# 2     [{'word': 'battle', 'Anger': 0.697000000000000...
# 6     [{'word': 'kill', 'Anger': 0.0, 'Fear': 0.9620...
# 8     [{'word': 'leave', 'Anger': 0.0, 'Fear': 0.0, ...
# 22    [{'word': 'die', 'Anger': 0.0, 'Fear': 0.76599...
# 25    [{'word': 'die', 'Anger': 0.0, 'Fear': 0.76599...
# ...                                                 ...
# 1271  [{'word': 'depressed', 'Anger': 0.297, 'Fear':...
# 1273  [{'word': 'corruption', 'Anger': 0.0, 'Fear': ...
# 1275  [{'word': 'afraid', 'Anger': 0.0, 'Fear': 0.84...
# 1279  [{'word': 'die', 'Anger': 0.0, 'Fear': 0.76599...
# 1285  [{'word': 'danger', 'Anger': 0.0, 'Fear': 0.80...
#
#                                        emotion_by_count  \
# 2     {'Anger': 2, 'Fear': 11, 'Disgust': 2, 'Sadnes...
# 6     {'Anger': 2, 'Fear': 2, 'Disgust': 0, 'Sadness...
# 8     {'Anger': 0, 'Fear': 2, 'Disgust': 0, 'Sadness...
# 22    {'Anger': 1, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 25    {'Anger': 0, 'Fear': 0, 'Disgust': 1, 'Sadness...
# ...                                                 ...
# 1271  {'Anger': 4, 'Fear': 3, 'Disgust': 0, 'Sadness...
# 1273  {'Anger': 0, 'Fear': 4, 'Disgust': 2, 'Sadness...
# 1275  {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 1279  {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 1285  {'Anger': 3, 'Fear': 10, 'Disgust': 0, 'Sadnes...
#
#                                        emotion_by_score  \
# 2     {'Anger': 6.7250000000000005, 'Fear': 7.694000...
# 6     {'Anger': 0.9059999999999999, 'Fear': 3.440000...
# 8     {'Anger': 0.561, 'Fear': 0.891, 'Disgust': 0.0...
# 22    {'Anger': 2.0919999999999996, 'Fear': 4.617, '...
# 25    {'Anger': 0.0, 'Fear': 0.7659999999999999, 'Di...
# ...                                                 ...
# 1271  {'Anger': 3.7439999999999998, 'Fear': 5.944, '...
# 1273  {'Anger': 0.7569999999999999, 'Fear': 4.709, '...
# 1275  {'Anger': 0.0, 'Fear': 1.6099999999999999, 'Di...
# 1279  {'Anger': 0.0, 'Fear': 2.235, 'Disgust': 0.422...
# 1285  {'Anger': 5.202999999999999, 'Fear': 12.612, '...
#
#      domain_emotion_by_count domain_emotion_by_score
# 2                       Fear                 Sadness
# 6                      Anger                 Sadness
# 8                       Fear                 Sadness
# 22                   Sadness                    Fear
# 25                   Disgust                 Sadness
# ...                      ...                     ...
# 1271                 Sadness                    Fear
# 1273                    Fear                 Sadness
# 1275                 Sadness                    Fear
# 1279                 Sadness                    Fear
# 1285                 Sadness                    Fear
#
# [343 rows x 6 columns]

# %% [markdown]
# ## Domain Emotions by Count

# %%
# domain emotion by count 
emo_counts =df_annotate['domain_emotion_by_count'].value_counts(normalize=True)
emo_counts
# Out:
# Sadness     0.392552
# Fear        0.325834
# Anger       0.187742
# Surprise    0.062064
# Disgust     0.031808
# Name: domain_emotion_by_count, dtype: float64

# %%
#bar chart - emotion by count
title = 'Suicidal Posts by Emotions' 
emo_counts.sort_values().plot(kind='barh', figsize=(10,6), title=title,width =0.8)
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
# piechart - emotion by count 
colors = ("powderblue","thistle","lightcoral","khaki","mediumaquamarine")
plt.pie(emo_counts, labels = emo_counts.index, autopct='%1.0f%%',colors=colors) #,textprops = dict(color ="grey"))
fig = plt.gcf()
fig.set_size_inches(7,7)

# %% [markdown]
# ## Domain Emotions by Score

# %%
# domain emotion by scores
emo_score_counts =df_annotate['domain_emotion_by_score'].value_counts(normalize=True)
emo_score_counts
# Out:
# Sadness     0.460047
# Fear        0.333592
# Anger       0.137316
# Disgust     0.035687
# Surprise    0.033359
# Name: domain_emotion_by_score, dtype: float64

# %%
#bar chart - emotion by score
title = 'Suicidal Posts by Emotions' 
emo_score_counts.sort_values().plot(kind='barh', figsize=(10,6), title=title, width=0.8)
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
# piechart - emotion by score
colors = ("powderblue","thistle","lightcoral","khaki","mediumaquamarine")
plt.pie(emo_score_counts,labels = emo_counts.index, autopct='%1.0f%%',colors=colors) #,textprops = dict(color ="grey"))
fig = plt.gcf()
fig.set_size_inches(7,7)

# %%
surprise =df_annotate.loc[df_annotate['domain_emotion_by_count']=='Surprise']
surprise
# Out:
#                                                    text  \
# 24    [find, meaning, life, really, dont, care, beli...
# 30    [ever, laugh, whenever, parent, think, future,...
# 59    [hi, im, british, male, weight, life, smoke, w...
# 76                                [reach, point, guess]
# 90    [boyfriend, really, busy, handle, college, his...
# ...                                                 ...
# 1216  [birthday, today, ive, never, celebration, ive...
# 1224  [long, long, journey, since, may, still, feel,...
# 1244  [cut, lot, gotten, bad, month, probably, start...
# 1265  [begin, month, im, computer, pay, online, bill...
# 1269  [one, year, ago, today, try, end, life, recent...
#
#                                               annotated  \
# 24    [{'word': 'illusion', 'Anger': 0.0, 'Fear': 0....
# 30    [{'word': 'laugh', 'Anger': 0.0, 'Fear': 0.0, ...
# 59    [{'word': 'weight', 'Anger': 0.0, 'Fear': 0.0,...
# 76    [{'word': 'guess', 'Anger': 0.0, 'Fear': 0.0, ...
# 90    [{'word': 'treat', 'Anger': 0.0, 'Fear': 0.0, ...
# ...                                                 ...
# 1216  [{'word': 'birthday', 'Anger': 0.0, 'Fear': 0....
# 1224  [{'word': 'warn', 'Anger': 0.0, 'Fear': 0.4529...
# 1244  [{'word': 'bad', 'Anger': 0.45299999999999996,...
# 1265  [{'word': 'electric', 'Anger': 0.0, 'Fear': 0....
# 1269  [{'word': 'die', 'Anger': 0.0, 'Fear': 0.76599...
#
#                                        emotion_by_count  \
# 24    {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 30    {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 59    {'Anger': 1, 'Fear': 12, 'Disgust': 2, 'Sadnes...
# 76    {'Anger': 0, 'Fear': 0, 'Disgust': 0, 'Sadness...
# 90    {'Anger': 0, 'Fear': 1, 'Disgust': 1, 'Sadness...
# ...                                                 ...
# 1216  {'Anger': 0, 'Fear': 2, 'Disgust': 0, 'Sadness...
# 1224  {'Anger': 1, 'Fear': 3, 'Disgust': 0, 'Sadness...
# 1244  {'Anger': 4, 'Fear': 3, 'Disgust': 2, 'Sadness...
# 1265  {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
# 1269  {'Anger': 0, 'Fear': 1, 'Disgust': 0, 'Sadness...
#
#                                        emotion_by_score  \
# 24    {'Anger': 0.692, 'Fear': 1.1520000000000001, '...
# 30    {'Anger': 0.0, 'Fear': 0.203, 'Disgust': 0.0, ...
# 59    {'Anger': 3.762, 'Fear': 10.748999999999999, '...
# 76    {'Anger': 0.0, 'Fear': 0.0, 'Disgust': 0.0, 'S...
# 90    {'Anger': 0.573, 'Fear': 1.0939999999999999, '...
# ...                                                 ...
# 1216  {'Anger': 0.667, 'Fear': 1.5630000000000002, '...
# 1224  {'Anger': 1.045, 'Fear': 1.9219999999999997, '...
# 1244  {'Anger': 5.903999999999999, 'Fear': 5.3459999...
# 1265  {'Anger': 0.33299999999999996, 'Fear': 0.621, ...
# 1269  {'Anger': 0.0, 'Fear': 0.9689999999999999, 'Di...
#
#      domain_emotion_by_count domain_emotion_by_score
# 24                  Surprise                Surprise
# 30                  Surprise                Surprise
# 59                  Surprise                    Fear
# 76                  Surprise                Surprise
# 90                  Surprise                    Fear
# ...                      ...                     ...
# 1216                Surprise                Surprise
# 1224                Surprise                Surprise
# 1244                Surprise                   Anger
# 1265                Surprise                Surprise
# 1269                Surprise                Surprise
#
# [80 rows x 6 columns]

# %%
data_clean.iloc[1244]
# Out:
# 'cut lot gotten bad month probably start early february quarantine hit utah school become online never much talker friend many dont date mental heath wasnt great begin didnt want get reject quiet kid fine panic start couple week start get depressed like say wasnt social problem theory lot shit happen two week push edge father isnt nice abusve physically mentally didnt high esteem born never told proud ive wasnt dad mom get divorce christmas thought good idea tell brother sister young opening present think wouldnt tell first mom say best next thing two week covid grandpa die heart go didnt really hit week later start cut always loathe go father every day would yell mess something thing think yell get head well doesnt also reason start cut thats right im tire want sleep edit someone really care add'

# %% [markdown]
# # ----------------------------------------------END----------------------------------------------------------

# %%
# save files for later use
emotion_post = pd.DataFrame(df_annotate['domain_emotion_by_count'])
emotion_post.to_pickle('emotion.pkl')

emotion_score =pd.DataFrame(df_annotate['domain_emotion_by_score'])
emotion_score.to_pickle('emotion_score.pkl')
